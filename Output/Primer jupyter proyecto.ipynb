# %%
#IMPORTAMOS PANDAS
import pandas as pd

# %%
#ABRIMOS EL CSV
Sharkys = pd.read_csv("/Users/santiagobermejo/Desktop/IRONHACK/Proyectos-Ironhack-0120/input/GSAF5.csv")

# %%
Sharkys.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
Sharkys["Case Number"].head(50)
# Out:
# 0     2016.09.18.c
# 1     2016.09.18.b
# 2     2016.09.18.a
# 3       2016.09.17
# 4       2016.09.15
# 5     2016.09.15.R
# 6       2016.09.11
# 7       2016.09.07
# 8       2016.09.06
# 9     2016.09.05.b
# 10    2016.09.05.a
# 11      2016.09.04
# 12      2016.09.01
# 13    2016.08.29.b
# 14    2016.08.29.a
# 15      2016.08.27
# 16      2016.08.25
# 17      2016.08.07
# 18      2016.08.06
# 19      2016.08.04
# 20      2016.07.29
# 21    2016.07.28.R
# 22      2016.07.28
# 23      2016.07.27
# 24      2016.07.26
# 25      2016.07.24
# 26    2016.07.23.b
# 27    2016.07.23.a
# 28      2016.07.20
# 29      2016.07.17
# 30    2016.07.16.b
# 31    2016.07.16.a
# 32      2016.07.15
# 33    2016.07.14.4
# 34    2016.07.08.R
# 35      2016.07.08
# 36    2016.07.07.b
# 37    2016.07.07.a
# 38      2016.07.06
# 39      2016.07.04
# 40      2016.06.27
# 41      2016.06.25
# 42      2016.06.24
# 43      2016.06.23
# 44    2016.06.21.b
# 45    2016.06.21.a
# 46    2016.06.15.b
# ...

# %%
Sharkys_attack = Sharkys[["Activity","Country","Area","Species "]]
Sharkys_attack
# Out:
#           Activity             Country               Area   Species
# 0          Surfing                 USA            Florida        NaN
# 1          Surfing                 USA            Florida        NaN
# 2          Surfing                 USA            Florida        NaN
# 3          Surfing           AUSTRALIA           Victoria        NaN
# 4          Surfing           AUSTRALIA           Victoria  2 m shark
# ...            ...                 ...                ...        ...
# 5987        Diving           AUSTRALIA  Western Australia        NaN
# 5988  Pearl diving           AUSTRALIA  Western Australia        NaN
# 5989      Swimming                 USA     North Carolina        NaN
# 5990           NaN              PANAMA                NaN        NaN
# 5991      Swimming  CEYLON (SRI LANKA)   Eastern Province        NaN
#
# [5992 rows x 4 columns]

# %%
Sharkys_attack_Country = Sharkys_attack[["Activity","Country","Area"]]["Country"].value_counts()
Sharkys_attack_Country.tail(50)
# Out:
# BRITISH ISLES                     1
# BRITISH NEW GUINEA                1
# MONACO                            1
# CURACAO                           1
# DJIBOUTI                          1
# GHANA                             1
# EQUATORIAL GUINEA / CAMEROON      1
# GABON                             1
# MAYOTTE                           1
# NICARAGUA                         1
# NEVIS                             1
# MEDITERRANEAN SEA?                1
# TASMAN SEA                        1
# ADMIRALTY ISLANDS                 1
# NORTHERN ARABIAN SEA              1
# MID-PACIFC OCEAN                  1
# ANGOLA                            1
# NORTH SEA                         1
# BRITISH VIRGIN ISLANDS            1
# St Helena                         1
# PALESTINIAN TERRITORIES           1
# RED SEA?                          1
# GEORGIA                           1
# WESTERN SAMOA                     1
# GUATEMALA                         1
# Between PORTUGAL & INDIA          1
# ...

# %%
Sharkys_attack_Area = Sharkys_attack[["Activity","Country","Area"]]["Area"].value_counts()
Sharkys_attack_Area.head(50)
# Out:
# Florida                          990
# New South Wales                  468
# Queensland                       300
# Hawaii                           282
# California                       276
# KwaZulu-Natal                    210
# Western Cape Province            188
# Western Australia                172
# Eastern Cape Province            156
# South Carolina                   145
# South Australia                  103
# North Carolina                   100
# Victoria                          81
# Texas                             71
# Pernambuco                        70
# Torres Strait                     70
# North Island                      65
# New Jersey                        49
# Tasmania                          41
# South Island                      39
# Oregon                            28
# New York                          27
# Northern Territory                23
# Central Province                  22
# Abaco Islands                     22
# ...

# %%
islas_reunion = Sharkys["Country"].value_counts()
islas_reunion
# Out:
# USA                     2116
# AUSTRALIA               1279
# SOUTH AFRICA             565
# PAPUA NEW GUINEA         133
# NEW ZEALAND              125
#                         ...
# MARTINIQUE                 1
# SAN DOMINGO                1
# NETHERLANDS ANTILLES       1
#  PHILIPPINES               1
# GUYANA                     1
# Name: Country, Length: 203, dtype: int64

# %%
islas_reunion = Sharkys[(Sharkys["Country"] == "REUNION") | (Sharkys["Country"]== "IRELAND")]
islas_reunion.tail()
# Out:
#        Case Number                 Date  Year          Type  Country  \
# 5056    1917.07.15            15-Jul-17  1917  Sea Disaster  IRELAND
# 5128  1913.00.00.d                 1913  1913    Unprovoked  REUNION
# 5129  1913.00.00.c                 1913  1913    Unprovoked  REUNION
# 5908       ND.0096              No date     0    Unprovoked  REUNION
# 5968       ND.0024  Between 1918 & 1939     0    Unprovoked  REUNION
#
#              Area               Location                        Activity  \
# 5056  Off Ireland  82 miles from Fastnet  Ship Mariston torpedoed & sunk
# 5128  Saint-Denis      Barachoise bridge          Swimming after his hat
# 5129  5aint-Denis              Barachois                        Swimming
# 5908   Grand'Anse             Petite-�le           yachtsman in a zodiac
# 5968  Saint-Denis              Barachois                        Swimming
#
#       Name Sex   ... Species     Investigator or Source  \
# ...

# %%
islas_reunion.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
islas_reunion[["Activity","Injury","Fatal (Y/N)","Species ","Time"]]
# Out:
#                                                Activity  \
# 15                                              Surfing
# 167                                             Surfing
# 197                                             Surfing
# 214                                             Surfing
# 226                                            Swimming
# 305                                             Surfing
# 384                                       Body boarding
# 431                               Swimming & snorkeling
# 454                                       Body boarding
# 532                                             Surfing
# 539                                             Surfing
# 589                                       Body boarding
# 623                          Free diving / spearfishing
# 633                                            Canoeing
# 642                                       Body boarding
# 672                             Kayaking or Wave skiing
# ...

# %%
islas_reunion["Fatal (Y/N)"].value_counts()
# Out:
# N    30
# Y    28
# Name: Fatal (Y/N), dtype: int64

# %%
USA = Sharkys[(Sharkys["Country"] == "USA") | (Sharkys["Country"]== "IRELAND")]
USA.head()
# Out:
#     Case Number       Date  Year        Type Country     Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked     USA  Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked     USA  Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked     USA  Florida
# 6    2016.09.11  11-Sep-16  2016  Unprovoked     USA  Florida
# 7    2016.09.07  07-Sep-16  2016  Unprovoked     USA   Hawaii
#
#                            Location  Activity            Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County   Surfing            male    M  ...
# 1  New Smyrna Beach, Volusia County   Surfing  Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County   Surfing            male    M  ...
# 6     Ponte Vedra, St. Johns County    Wading            male    M  ...
# 7                      Makaha, Oahu  Swimming          female    F  ...
#
#            Species        Investigator or Source                        pdf  \
# 0               NaN  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# ...

# %%
USA["Fatal (Y/N)"].value_counts()
# Out:
# N          1841
# Y           247
# UNKNOWN      26
# n             1
# Name: Fatal (Y/N), dtype: int64

# %%
Sharkys["Species "].value_counts().head(20)
# Out:
# White shark                        161
# Shark involvement not confirmed     80
# Tiger shark                         68
# Bull shark                          52
# 6' shark                            40
# 4' shark                            39
# 1.8 m [6'] shark                    35
# 1.5 m [5'] shark                    32
# 1.2 m [4'] shark                    27
# 5' shark                            25
# 3' shark                            25
# 4' to 5' shark                      23
# 2 m shark                           22
# 3 m [10'] shark                     22
# No shark involvement                21
# Wobbegong shark                     20
# 3' to 4' shark                      18
# 3 m shark                           16
# 2.4 m [8'] shark                    16
# 3.7 m [12'] shark                   15
# Name: Species , dtype: int64

# %%
islas_reunion_df = pd.DataFrame(islas_reunion)
islas_reunion_df
# Out:
#        Case Number                  Date  Year          Type  Country  \
# 15      2016.08.27             27-Aug-16  2016    Unprovoked  REUNION
# 167     2015.07.22             22-Jul-15  2015    Unprovoked  REUNION
# 197     2015.06.01             01-Jun-15  2015    Unprovoked  REUNION
# 214     2015.04.12             12-Apr-15  2015    Unprovoked  REUNION
# 226     2015.02.14             14-Feb-15  2015    Unprovoked  REUNION
# 305     2014.07.22             22-Jul-14  2014    Unprovoked  REUNION
# 384   2013.10.26.b             26-Oct-13  2013    Unprovoked  REUNION
# 431     2013.07.15             15-Jul-13  2013    Unprovoked  REUNION
# 454   2013.05.08.a             08-May-13  2013    Unprovoked  REUNION
# 532     2012.08.05             06-Aug-12  2012    Unprovoked  REUNION
# 539     2012.07.23             23-Jul-12  2012    Unprovoked  REUNION
# 589     2012.03.05             05-Mar-12  2012    Unprovoked  REUNION
# ...

# %%
islas_reunion_df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
islas_reunion_df
# Out:
#        Case Number                  Date  Year          Type  Country  \
# 15      2016.08.27             27-Aug-16  2016    Unprovoked  REUNION
# 167     2015.07.22             22-Jul-15  2015    Unprovoked  REUNION
# 197     2015.06.01             01-Jun-15  2015    Unprovoked  REUNION
# 214     2015.04.12             12-Apr-15  2015    Unprovoked  REUNION
# 226     2015.02.14             14-Feb-15  2015    Unprovoked  REUNION
# 305     2014.07.22             22-Jul-14  2014    Unprovoked  REUNION
# 384   2013.10.26.b             26-Oct-13  2013    Unprovoked  REUNION
# 431     2013.07.15             15-Jul-13  2013    Unprovoked  REUNION
# 454   2013.05.08.a             08-May-13  2013    Unprovoked  REUNION
# 532     2012.08.05             06-Aug-12  2012    Unprovoked  REUNION
# 539     2012.07.23             23-Jul-12  2012    Unprovoked  REUNION
# 589     2012.03.05             05-Mar-12  2012    Unprovoked  REUNION
# ...

# %%
del islas_reunion_df["href formula"]

# %%
del islas_reunion_df["href"]

# %%
del islas_reunion_df["Case Number.1"]

# %%
del islas_reunion_df["original order"]

# %%
del islas_reunion_df["Unnamed: 22"]

# %%
del islas_reunion_df["Case Number.2"]

# %%
del islas_reunion_df["Unnamed: 23"]

# %%
islas_reunion_df[["Activity","Fatal (Y/N)"]]["Activity"].value_counts()
# Out:
# Surfing                                                20
# Body boarding                                           8
# Spearfishing                                            7
# Swimming                                                3
# Diving                                                  3
# Bathing                                                 1
# Swimming after being swept into sea by a large wave     1
# Canoeing                                                1
# Kayaking or Wave skiing                                 1
# p�cheur de bichiques                                    1
# Ship Mariston torpedoed & sunk                          1
# yachtsman in a zodiac                                   1
# Body-boarding                                           1
# Swimming after his hat                                  1
# Canoe with 3 men onboard sank                           1
# Free diving / spearfishing                              1
# ...

# %%
islas_reunion_df.describe()
# Out:
#               Year
# count    58.000000
# mean   1927.724138
# std     368.155278
# min       0.000000
# 25%    1992.000000
# 50%    1999.000000
# 75%    2011.000000
# max    2016.000000

# %%
human_action = islas_reunion["Type"]

# %%
human_action.value_counts()
# Out:
# Unprovoked      55
# Boat             2
# Sea Disaster     1
# Name: Type, dtype: int64

# %%
human_action_global = Sharkys["Type"]

# %%
human_action_global.value_counts()
# Out:
# Unprovoked      4386
# Provoked         557
# Invalid          519
# Sea Disaster     220
# Boat             200
# Boating          110
# Name: Type, dtype: int64

# %%
islas_reunion.isnull().sum()
# Out:
# Case Number                0
# Date                       0
# Year                       0
# Type                       0
# Country                    0
# Area                       8
# Location                  10
# Activity                   3
# Name                       9
# Sex                        7
# Age                       26
# Injury                     0
# Fatal (Y/N)                0
# Time                      18
# Species                   29
# Investigator or Source     0
# pdf                        0
# dtype: int64

# %%
Sharkys
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
SOUTH AFRICA
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-cd0785203ad0> in <module>
# ----> 1 Sharkys.value_counts()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
SA = Sharkys[(Sharkys["Country"] == "SOUTH AFRICA") | (Sharkys["Country"]== "IRELAND")]

# %%
SA
# Out:
#      Case Number                                               Date  Year  \
# 43    2016.06.23                                          23-Jun-16  2016
# 68    2016.04.22                                          22-Apr-16  2016
# 94    2016.01.29                                          29-Jan-16  2016
# 103   2015.12.26                                          26-Dec-15  2015
# 111   2015.12.08                                          08-Dec-15  2015
# ...          ...                                                ...   ...
# 5971     ND.0021                                            No date     0
# 5975     ND.0017                                        Before 1921     0
# 5976     ND.0016                                        Before 1921     0
# 5979     ND.0013  No date (3 days after preceding incident) & pr...     0
# 5980     ND.0012                        Before          19-Jul-1913     0
#
#             Type       Country                   Area  \
# ...

# %%
SA[["Activity","Injury","Fatal (Y/N)","Species ","Time"]]
# Out:
#                                                Activity  \
# 43                                         Spearfishing
# 68                                          Surf-skiing
# 94                                        Kayak fishing
# 103                                       Kayak Fishing
# 111                                   Swimming / Wading
# ...                                                 ...
# 5971  Swimming in pool formed by construction of a w...
# 5975        Crew swimming alongside their anchored ship
# 5976                                 4 men were bathing
# 5979                                            Fishing
# 5980                                             Wading
#
#                                                  Injury Fatal (Y/N)  \
# 43                    Injuries to left leg & right hand           N
# 68                           No injury, surf-ski bitten           N
# 94                      No injury, shark capsized kayak           N
# ...

# %%
SA["Fatal (Y/N)"].value_counts()
# Out:
# N          422
# Y          138
# UNKNOWN      5
# #VALUE!      1
# Name: Fatal (Y/N), dtype: int64

# %%
AUS = Sharkys[(Sharkys["Country"] == "AUSTRALIA") | (Sharkys["Country"]== "IRELAND")]

# %%
AUS[["Activity","Injury","Fatal (Y/N)","Species ","Time"]]
# Out:
#           Activity                                    Injury Fatal (Y/N)  \
# 3          Surfing              Struck by fin on chest & leg           N
# 4          Surfing     No injury: Knocked off board by shark           N
# 5          Fishing  Shark rammed boat. No injury to occupant           N
# 10         Surfing   No inury, board broken in half by shark           N
# 22        Kayaking  No injury, shark nudged kayak repeatedly           N
# ...            ...                                       ...         ...
# 5984       Fishing                                     FATAL           Y
# 5985       Fishing                                     FATAL           Y
# 5986      Swimming                                     FATAL           Y
# 5987        Diving                                     FATAL           Y
# 5988  Pearl diving                                     FATAL           Y
#
#                                                Species             Time
# ...

# %%
AUS["Fatal (Y/N)"].value_counts()
# Out:
# N          903
# Y          342
# UNKNOWN     27
#  N           6
# N            1
# Name: Fatal (Y/N), dtype: int64

# %%
islas_reunion["Type"].value_counts()
# Out:
# Unprovoked      55
# Boat             2
# Sea Disaster     1
# Name: Type, dtype: int64

# %%
islas_reunion["Activity"].value_counts()
# Out:
# Surfing                                                20
# Body boarding                                           8
# Spearfishing                                            7
# Swimming                                                3
# Diving                                                  3
# Bathing                                                 1
# Swimming after being swept into sea by a large wave     1
# Canoeing                                                1
# Kayaking or Wave skiing                                 1
# p�cheur de bichiques                                    1
# Ship Mariston torpedoed & sunk                          1
# yachtsman in a zodiac                                   1
# Body-boarding                                           1
# Swimming after his hat                                  1
# Canoe with 3 men onboard sank                           1
# Free diving / spearfishing                              1
# ...

# %%
IR = Sharkys.iloc[Sharkys['Country']] == "REUNION"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-0c9ddf4072ed> in <module>
# ----> 1 IR =Sharkys.iloc[Sharkys['Country']] == "REUNION"
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2140             key = np.asarray(key)
#    2141
# -> 2142         if com.is_bool_indexer(key):
#    2143             self._validate_key(key, axis)
#    2144             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
USA_global = Sharkys[(Sharkys.Country == "USA")]

# %%
USA_global
# Out:
#        Case Number                         Date  Year        Type Country  \
# 0     2016.09.18.c                    18-Sep-16  2016  Unprovoked     USA
# 1     2016.09.18.b                    18-Sep-16  2016  Unprovoked     USA
# 2     2016.09.18.a                    18-Sep-16  2016  Unprovoked     USA
# 6       2016.09.11                    11-Sep-16  2016  Unprovoked     USA
# 7       2016.09.07                    07-Sep-16  2016  Unprovoked     USA
# ...            ...                          ...   ...         ...     ...
# 5939       ND.0056                  Before 1958     0  Unprovoked     USA
# 5973       ND.0019                  Before 1921     0  Unprovoked     USA
# 5978       ND.0014  Before          17-Jul-1916     0  Unprovoked     USA
# 5982       ND.0010                   Circa 1862     0  Unprovoked     USA
# 5989       ND.0003                    1900-1905     0  Unprovoked     USA
#
#                  Area                                 Location  Activity  \
# ...

# %%
USA_global.drop(columns = ["Unnamed: 23"])
# Out:
#        Case Number                         Date  Year        Type Country  \
# 0     2016.09.18.c                    18-Sep-16  2016  Unprovoked     USA
# 1     2016.09.18.b                    18-Sep-16  2016  Unprovoked     USA
# 2     2016.09.18.a                    18-Sep-16  2016  Unprovoked     USA
# 6       2016.09.11                    11-Sep-16  2016  Unprovoked     USA
# 7       2016.09.07                    07-Sep-16  2016  Unprovoked     USA
# ...            ...                          ...   ...         ...     ...
# 5939       ND.0056                  Before 1958     0  Unprovoked     USA
# 5973       ND.0019                  Before 1921     0  Unprovoked     USA
# 5978       ND.0014  Before          17-Jul-1916     0  Unprovoked     USA
# 5982       ND.0010                   Circa 1862     0  Unprovoked     USA
# 5989       ND.0003                    1900-1905     0  Unprovoked     USA
#
#                  Area                                 Location  Activity  \
# ...

# %%
GRECIA_global = Sharkys[(Sharkys.Country == "GRECIA")]

# %%
GRECIA_global
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
y = dangerest[dangerest["Fatal"]=="Y"].groupby("Country").agg({"Fatal":"count"}).sort_values('Fatal', ascending = False)
y["TotalAttacks"] = dangerest[dangerest["Fatal"].isin(["Y","N"])].groupby("Country").agg({"Fatal":"count"}).sort_values('Fatal', ascending = False)
y["Percentage"] = y["Fatal"]/y["TotalAttacks"]
display(y.head(14))
